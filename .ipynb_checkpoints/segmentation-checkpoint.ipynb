# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.cluster import KMeans
import pickle as pickle
import os
import datetime as dt
import squarify as squarify
import base64
import csv
from sklearn.preprocessing import StandardScaler
import re

# %%
df = pd.read_csv("data/segmentasicustomerwsh.csv")

# %%
print(df)
# Out:
#     id_transaksi id_customer tanggal_transaksi  jumlah_transaksi  \
# 0           T001     WSH001           1/7/2023                 7
# 1           T002      WSH002          1/7/2023                13
# 2           T003      WSH003          1/7/2023                21
# 3           T004      WSH004          1/7/2023                 5
# 4           T005      WSH002          1/7/2023                 6
# ..           ...         ...               ...               ...
# 585         T586      WSH002         8/11/2023                 8
# 586         T587      WSH008         8/11/2023                 3
# 587         T588      WSH018         8/11/2023                 9
# 588         T589      WSH019         8/11/2023                 8
# 589         T590      WSH010         9/11/2023                 6
#
#      total_transaksi                                   item_transaksi
# 0              61500                               C(3); KK(2); SL(2)
# 1             116500     BM(2); BT(1); C(2); R(2); S(1); SB(2); SL(3)
# 2             183000  BB(3); BH(3); BM(3); BT(3); KL(3); KU(3); MA(3)
# 3              42500                                             C(5)
# 4              50000                              KK(2); KM(2); KU(2)
# ..               ...                                              ...
# 585            74500             BB(2); C(1); KU(2); O(1); S(1); T(1)
# 586            22500                                     BT(2); KL(1)
# 587            82000                 DK(4); KM(1); MP(2); PP(1); T(1)
# 588            66500           BB(1); BT(2); KK(2); O(1); SB(1); T(1)
# 589            54000                        DK(2); KK(2); MA(1); P(1)
#
# [590 rows x 6 columns]

# %%
df.head()
# Out:
#   id_transaksi id_customer tanggal_transaksi  jumlah_transaksi  \
# 0         T001     WSH001           1/7/2023                 7
# 1         T002      WSH002          1/7/2023                13
# 2         T003      WSH003          1/7/2023                21
# 3         T004      WSH004          1/7/2023                 5
# 4         T005      WSH002          1/7/2023                 6
#
#    total_transaksi                                   item_transaksi
# 0            61500                               C(3); KK(2); SL(2)
# 1           116500     BM(2); BT(1); C(2); R(2); S(1); SB(2); SL(3)
# 2           183000  BB(3); BH(3); BM(3); BT(3); KL(3); KU(3); MA(3)
# 3            42500                                             C(5)
# 4            50000                              KK(2); KM(2); KU(2)

# %%
df = pd.DataFrame(df)

# %%
print(df)
# Out:
#     id_transaksi id_customer tanggal_transaksi  jumlah_transaksi  \
# 0           T001     WSH001           1/7/2023                 7
# 1           T002      WSH002          1/7/2023                13
# 2           T003      WSH003          1/7/2023                21
# 3           T004      WSH004          1/7/2023                 5
# 4           T005      WSH002          1/7/2023                 6
# ..           ...         ...               ...               ...
# 585         T586      WSH002         8/11/2023                 8
# 586         T587      WSH008         8/11/2023                 3
# 587         T588      WSH018         8/11/2023                 9
# 588         T589      WSH019         8/11/2023                 8
# 589         T590      WSH010         9/11/2023                 6
#
#      total_transaksi                                   item_transaksi
# 0              61500                               C(3); KK(2); SL(2)
# 1             116500     BM(2); BT(1); C(2); R(2); S(1); SB(2); SL(3)
# 2             183000  BB(3); BH(3); BM(3); BT(3); KL(3); KU(3); MA(3)
# 3              42500                                             C(5)
# 4              50000                              KK(2); KM(2); KU(2)
# ..               ...                                              ...
# 585            74500             BB(2); C(1); KU(2); O(1); S(1); T(1)
# 586            22500                                     BT(2); KL(1)
# 587            82000                 DK(4); KM(1); MP(2); PP(1); T(1)
# 588            66500           BB(1); BT(2); KK(2); O(1); SB(1); T(1)
# 589            54000                        DK(2); KK(2); MA(1); P(1)
#
# [590 rows x 6 columns]

# %%
df['id_customer'] = df['id_customer'].str.strip().str.lower()

# %%
df.head()
# Out:
#   id_transaksi id_customer tanggal_transaksi  jumlah_transaksi  \
# 0         T001      wsh001          1/7/2023                 7
# 1         T002      wsh002          1/7/2023                13
# 2         T003      wsh003          1/7/2023                21
# 3         T004      wsh004          1/7/2023                 5
# 4         T005      wsh002          1/7/2023                 6
#
#    total_transaksi                                   item_transaksi
# 0            61500                               C(3); KK(2); SL(2)
# 1           116500     BM(2); BT(1); C(2); R(2); S(1); SB(2); SL(3)
# 2           183000  BB(3); BH(3); BM(3); BT(3); KL(3); KU(3); MA(3)
# 3            42500                                             C(5)
# 4            50000                              KK(2); KM(2); KU(2)

# %%
print("Jumlah data yang memiliki missing null")
df.isnull().sum()
(df == 'NA').sum()
# Out:
# Jumlah data yang memiliki missing null
# id_transaksi         0
# id_customer          0
# tanggal_transaksi    0
# jumlah_transaksi     0
# total_transaksi      0
# item_transaksi       0
# dtype: int64

# %%
print("Duplicate Data")
df.duplicated().sum()
# Out:
# Duplicate Data
# 0

# %%
#Menghapus nilai null
df.replace('NA', pd.NA, inplace=True)
df.dropna(inplace=True)

# %%
#menghapus duplicate row
df.drop_duplicates(inplace=True)

# %%
print(df)
# Out:
#     id_transaksi id_customer tanggal_transaksi  jumlah_transaksi  \
# 0           T001      wsh001          1/7/2023                 7
# 1           T002      wsh002          1/7/2023                13
# 2           T003      wsh003          1/7/2023                21
# 3           T004      wsh004          1/7/2023                 5
# 4           T005      wsh002          1/7/2023                 6
# ..           ...         ...               ...               ...
# 585         T586      wsh002         8/11/2023                 8
# 586         T587      wsh008         8/11/2023                 3
# 587         T588      wsh018         8/11/2023                 9
# 588         T589      wsh019         8/11/2023                 8
# 589         T590      wsh010         9/11/2023                 6
#
#      total_transaksi                                   item_transaksi
# 0              61500                               C(3); KK(2); SL(2)
# 1             116500     BM(2); BT(1); C(2); R(2); S(1); SB(2); SL(3)
# 2             183000  BB(3); BH(3); BM(3); BT(3); KL(3); KU(3); MA(3)
# 3              42500                                             C(5)
# 4              50000                              KK(2); KM(2); KU(2)
# ..               ...                                              ...
# 585            74500             BB(2); C(1); KU(2); O(1); S(1); T(1)
# 586            22500                                     BT(2); KL(1)
# 587            82000                 DK(4); KM(1); MP(2); PP(1); T(1)
# 588            66500           BB(1); BT(2); KK(2); O(1); SB(1); T(1)
# 589            54000                        DK(2); KK(2); MA(1); P(1)
#
# [590 rows x 6 columns]

# %%
df['tanggal_transaksi']=pd.to_datetime(df['tanggal_transaksi'], format='%d-%m-%Y')

# %%
print(df['tanggal_transaksi'])
# Out:
# 0     2023-07-01
# 1     2023-07-01
# 2     2023-07-01
# 3     2023-07-01
# 4     2023-07-01
#          ...
# 585   2023-11-08
# 586   2023-11-08
# 587   2023-11-08
# 588   2023-11-08
# 589   2023-11-09
# Name: tanggal_transaksi, Length: 590, dtype: datetime64[ns]

# %%
data = df[['id_transaksi','id_customer','tanggal_transaksi','jumlah_transaksi', 'total_transaksi']].sort_values(by="tanggal_transaksi", ascending=False)
print(data)
# Out:
#     id_transaksi id_customer tanggal_transaksi  jumlah_transaksi  \
# 589         T590      wsh010        2023-11-09                 6
# 588         T589      wsh019        2023-11-08                 8
# 587         T588      wsh018        2023-11-08                 9
# 586         T587      wsh008        2023-11-08                 3
# 585         T586      wsh002        2023-11-08                 8
# ..           ...         ...               ...               ...
# 1           T002      wsh002        2023-07-01                13
# 5           T006      wsh010        2023-07-01                 9
# 6           T007      wsh005        2023-07-01                 8
# 7           T008      wsh006        2023-07-01                 7
# 0           T001      wsh001        2023-07-01                 7
#
#      total_transaksi
# 589            54000
# 588            66500
# 587            82000
# 586            22500
# 585            74500
# ..               ...
# 1             116500
# 5              81000
# 6              72000
# 7              61500
# 0              61500
#
# [590 rows x 5 columns]

# %%
data.nunique()
# Out:
# id_transaksi         590
# id_customer           38
# tanggal_transaksi    131
# jumlah_transaksi      18
# total_transaksi      150
# dtype: int64

# %%
print("Transactions timeframe from {} to {}".format(data['tanggal_transaksi'].min(), data['tanggal_transaksi'].max()))
# Out:
# Transactions timeframe from 2023-07-01 00:00:00 to 2023-11-09 00:00:00

# %%
recent_date = data['tanggal_transaksi'].max()

# %%
Recency = data.groupby(['id_customer']).agg({'tanggal_transaksi': lambda x: (recent_date - x.max()).days}).rename(columns={'tanggal_transaksi':'Recency'})
Recency
# Out:
#              Recency
# id_customer
# wsh001             4
# wsh002             1
# wsh003             5
# wsh004             9
# wsh005            15
# wsh006            36
# wsh007             5
# wsh008             1
# wsh009             5
# wsh010             0
# wsh011             5
# wsh012             2
# wsh013             2
# wsh014             5
# wsh015            20
# wsh016             8
# wsh017            12
# wsh018             1
# wsh019             1
# wsh020             7
# wsh021             4
# wsh022            11
# wsh023            30
# wsh024            19
# wsh025            15
# wsh026             8
# wsh027             3
# wsh028            19
# wsh029             4
# wsh030             3
# wsh031             3
# wsh032             5
# wsh033            10
# wsh034             5
# wsh035             5
# wsh036             6
# wsh037            25
# wsh038             2

# %%
Frequency = data.groupby(['id_customer']).agg({'id_transaksi': lambda x:len(x)}).rename(columns={'id_transaksi':'Frequency'})
Frequency
# Out:
#              Frequency
# id_customer
# wsh001              32
# wsh002              21
# wsh003              18
# wsh004              34
# wsh005              20
# wsh006              13
# wsh007              21
# wsh008              30
# wsh009              23
# wsh010              22
# wsh011              30
# wsh012              25
# wsh013              11
# wsh014              26
# wsh015              17
# wsh016               9
# wsh017              15
# wsh018              19
# wsh019              23
# wsh020              21
# wsh021              19
# wsh022              10
# wsh023              11
# wsh024              11
# wsh025               7
# wsh026               6
# wsh027               8
# wsh028               7
# wsh029              13
# wsh030              13
# wsh031              17
# wsh032              12
# wsh033               7
# wsh034               7
# wsh035               5
# wsh036               4
# wsh037               1
# wsh038               2

# %%
Monetary = data.groupby(['id_customer']).agg({'total_transaksi': lambda x:x.sum()}).rename(columns={'total_transaksi':'Monetary'})
Monetary
# Out:
#              Monetary
# id_customer
# wsh001        2101000
# wsh002        1157000
# wsh003        1227000
# wsh004        1759000
# wsh005        1274500
# wsh006         740000
# wsh007        1233500
# wsh008        1778000
# wsh009        1439000
# wsh010        1394000
# wsh011        1721500
# wsh012        1389000
# wsh013         783500
# wsh014        1679000
# wsh015         835000
# wsh016         474000
# wsh017         916500
# wsh018         951500
# wsh019        1279500
# wsh020        1221500
# wsh021        1092000
# wsh022         400000
# wsh023         575500
# wsh024         717500
# wsh025         359500
# wsh026         294000
# wsh027         553500
# wsh028         324500
# wsh029         816000
# wsh030         582000
# wsh031        1161000
# wsh032         693000
# wsh033         293500
# wsh034         446500
# wsh035         174000
# wsh036         161500
# wsh037          84000
# wsh038          87000

# %%
RFM = pd.concat([Recency,Frequency,Monetary], axis=1)
RFM
# Out:
#              Recency  Frequency  Monetary
# id_customer
# wsh001             4         32   2101000
# wsh002             1         21   1157000
# wsh003             5         18   1227000
# wsh004             9         34   1759000
# wsh005            15         20   1274500
# wsh006            36         13    740000
# wsh007             5         21   1233500
# wsh008             1         30   1778000
# wsh009             5         23   1439000
# wsh010             0         22   1394000
# wsh011             5         30   1721500
# wsh012             2         25   1389000
# wsh013             2         11    783500
# wsh014             5         26   1679000
# wsh015            20         17    835000
# wsh016             8          9    474000
# wsh017            12         15    916500
# wsh018             1         19    951500
# wsh019             1         23   1279500
# wsh020             7         21   1221500
# wsh021             4         19   1092000
# wsh022            11         10    400000
# wsh023            30         11    575500
# wsh024            19         11    717500
# wsh025            15          7    359500
# wsh026             8          6    294000
# wsh027             3          8    553500
# wsh028            19          7    324500
# wsh029             4         13    816000
# wsh030             3         13    582000
# wsh031             3         17   1161000
# wsh032             5         12    693000
# wsh033            10          7    293500
# wsh034             5          7    446500
# wsh035             5          5    174000
# wsh036             6          4    161500
# wsh037            25          1     84000
# wsh038             2          2     87000

# %%
 df_RFM = data.groupby('id_customer').agg({
            'tanggal_transaksi': lambda x: (recent_date - x.max()).days, # Recency
            'id_customer': 'count', # Frequency
            'total_transaksi': lambda x: (x.sum()) # Monetary
        }).rename(columns={'tanggal_transaksi': 'Recency', 'id_customer': 'Frequency', 'total_transaksi': 'Monetary'})
df_RFM
# Out:
#              Recency  Frequency  Monetary
# id_customer
# wsh001             4         32   2101000
# wsh002             1         21   1157000
# wsh003             5         18   1227000
# wsh004             9         34   1759000
# wsh005            15         20   1274500
# wsh006            36         13    740000
# wsh007             5         21   1233500
# wsh008             1         30   1778000
# wsh009             5         23   1439000
# wsh010             0         22   1394000
# wsh011             5         30   1721500
# wsh012             2         25   1389000
# wsh013             2         11    783500
# wsh014             5         26   1679000
# wsh015            20         17    835000
# wsh016             8          9    474000
# wsh017            12         15    916500
# wsh018             1         19    951500
# wsh019             1         23   1279500
# wsh020             7         21   1221500
# wsh021             4         19   1092000
# wsh022            11         10    400000
# wsh023            30         11    575500
# wsh024            19         11    717500
# wsh025            15          7    359500
# wsh026             8          6    294000
# wsh027             3          8    553500
# wsh028            19          7    324500
# wsh029             4         13    816000
# wsh030             3         13    582000
# wsh031             3         17   1161000
# wsh032             5         12    693000
# wsh033            10          7    293500
# wsh034             5          7    446500
# wsh035             5          5    174000
# wsh036             6          4    161500
# wsh037            25          1     84000
# wsh038             2          2     87000

# %%
from sklearn.preprocessing import StandardScaler

df_RFM_normalized = df_RFM.copy()  # Create a copy to avoid modifying the original DataFrame
        
        # Initialize the MinMaxScaler
scaler = StandardScaler()

        # Normalize the 'Recency', 'Frequency', and 'Monetary' columns
df_RFM_normalized[['Recency', 'Frequency', 'Monetary']] = scaler.fit_transform(df_RFM[['Recency', 'Frequency', 'Monetary']])
df_RFM_normalized
# Out:
#               Recency  Frequency  Monetary
# id_customer
# wsh001      -0.534444   1.928977  2.271838
# wsh002      -0.894956   0.640938  0.487359
# wsh003      -0.414273   0.289655  0.619683
# wsh004       0.066410   2.163166  1.625342
# wsh005       0.787435   0.523844  0.709474
# wsh006       3.311021  -0.295818 -0.300912
# wsh007      -0.414273   0.640938  0.631970
# wsh008      -0.894956   1.694789  1.661259
# wsh009      -0.414273   0.875127  1.020434
# wsh010      -1.015127   0.758033  0.935369
# wsh011      -0.414273   1.694789  1.554455
# wsh012      -0.774785   1.109316  0.925917
# wsh013      -0.774785  -0.530007 -0.218682
# wsh014      -0.414273   1.226411  1.474115
# wsh015       1.388288   0.172560 -0.121330
# wsh016      -0.053761  -0.764196 -0.803742
# wsh017       0.426922  -0.061629  0.032733
# wsh018      -0.894956   0.406749  0.098895
# wsh019      -0.894956   0.875127  0.718925
# wsh020      -0.173931   0.640938  0.609286
# wsh021      -0.534444   0.406749  0.364487
# wsh022       0.306752  -0.647101 -0.943627
# wsh023       2.589996  -0.530007 -0.611872
# wsh024       1.268118  -0.530007 -0.343445
# wsh025       0.787435  -0.998385 -1.020185
# wsh026      -0.053761  -1.115479 -1.144003
# wsh027      -0.654614  -0.881290 -0.653460
# wsh028       1.268118  -0.998385 -1.086347
# wsh029      -0.534444  -0.295818 -0.157246
# wsh030      -0.654614  -0.295818 -0.599585
# wsh031      -0.654614   0.172560  0.494920
# wsh032      -0.414273  -0.412912 -0.389758
# wsh033       0.186581  -0.998385 -1.144948
# wsh034      -0.414273  -0.998385 -0.855726
# wsh035      -0.414273  -1.232573 -1.370843
# wsh036      -0.294102  -1.349668 -1.394472
# wsh037       1.989142  -1.700951 -1.540973
# wsh038      -0.774785  -1.583857 -1.535302

# %%
sse = {}

for k in range(1, 20):
    kmeans = KMeans(n_clusters=k, random_state=0, n_init=10)
    kmeans.fit(df_RFM_normalized)
    sse[k] = kmeans.inertia_
    
fig, ax = plt.subplots()
ax.set_title('Metode Elbow')
ax.set_xlabel('Jumlah kluster (K)')
ax.set_ylabel('Jumlah kuadrat jarak')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()), ax=ax)
# Out:
# <AxesSubplot: title={'center': 'Metode Elbow'}, xlabel='Jumlah kluster (K)', ylabel='Jumlah kuadrat jarak'>

# %%
n_cluster = 3
model = KMeans(n_clusters=n_cluster, random_state=42)
model.fit( df_RFM_normalized)
kmeans =  df_RFM_normalized.copy()
kmeans['Segmen'] = (model.labels_ +1)

print('RFM Analysis DataFrame with Cluster')
kmeans
# Out:
# RFM Analysis DataFrame with Cluster
#               Recency  Frequency  Monetary  Segmen
# id_customer
# wsh001      -0.534444   1.928977  2.271838       2
# wsh002      -0.894956   0.640938  0.487359       2
# wsh003      -0.414273   0.289655  0.619683       2
# wsh004       0.066410   2.163166  1.625342       2
# wsh005       0.787435   0.523844  0.709474       2
# wsh006       3.311021  -0.295818 -0.300912       3
# wsh007      -0.414273   0.640938  0.631970       2
# wsh008      -0.894956   1.694789  1.661259       2
# wsh009      -0.414273   0.875127  1.020434       2
# wsh010      -1.015127   0.758033  0.935369       2
# wsh011      -0.414273   1.694789  1.554455       2
# wsh012      -0.774785   1.109316  0.925917       2
# wsh013      -0.774785  -0.530007 -0.218682       1
# wsh014      -0.414273   1.226411  1.474115       2
# wsh015       1.388288   0.172560 -0.121330       3
# wsh016      -0.053761  -0.764196 -0.803742       1
# wsh017       0.426922  -0.061629  0.032733       1
# wsh018      -0.894956   0.406749  0.098895       2
# wsh019      -0.894956   0.875127  0.718925       2
# wsh020      -0.173931   0.640938  0.609286       2
# wsh021      -0.534444   0.406749  0.364487       2
# wsh022       0.306752  -0.647101 -0.943627       1
# wsh023       2.589996  -0.530007 -0.611872       3
# wsh024       1.268118  -0.530007 -0.343445       3
# wsh025       0.787435  -0.998385 -1.020185       1
# wsh026      -0.053761  -1.115479 -1.144003       1
# wsh027      -0.654614  -0.881290 -0.653460       1
# wsh028       1.268118  -0.998385 -1.086347       3
# wsh029      -0.534444  -0.295818 -0.157246       1
# wsh030      -0.654614  -0.295818 -0.599585       1
# wsh031      -0.654614   0.172560  0.494920       2
# wsh032      -0.414273  -0.412912 -0.389758       1
# wsh033       0.186581  -0.998385 -1.144948       1
# wsh034      -0.414273  -0.998385 -0.855726       1
# wsh035      -0.414273  -1.232573 -1.370843       1
# wsh036      -0.294102  -1.349668 -1.394472       1
# wsh037       1.989142  -1.700951 -1.540973       3
# wsh038      -0.774785  -1.583857 -1.535302       1

# %%
kmeans_data=kmeans.groupby('Segmen').agg({'Segmen': 'count'})
kmeans_data
# Out:
#         Segmen
# Segmen
# 1           15
# 2           17
# 3            6

# %%
def func(row):
    if row["Segmen"] == 3:
        return "Platinum"
    elif row["Segmen"] == 4:
        return "Gold"
    elif row["Segmen"] == 2:
        return "Silver"
    else:
        return "Bronze"

kmeans['Segmen']=kmeans.apply(func, axis=1)

kmeans
# Out:
#               Recency  Frequency  Monetary  Segmen
# id_customer
# wsh001      -0.534444   1.928977  2.271838  Bronze
# wsh002      -0.894956   0.640938  0.487359  Bronze
# wsh003      -0.414273   0.289655  0.619683  Bronze
# wsh004       0.066410   2.163166  1.625342  Bronze
# wsh005       0.787435   0.523844  0.709474  Bronze
# wsh006       3.311021  -0.295818 -0.300912  Bronze
# wsh007      -0.414273   0.640938  0.631970  Bronze
# wsh008      -0.894956   1.694789  1.661259  Bronze
# wsh009      -0.414273   0.875127  1.020434  Bronze
# wsh010      -1.015127   0.758033  0.935369  Bronze
# wsh011      -0.414273   1.694789  1.554455  Bronze
# wsh012      -0.774785   1.109316  0.925917  Bronze
# wsh013      -0.774785  -0.530007 -0.218682  Bronze
# wsh014      -0.414273   1.226411  1.474115  Bronze
# wsh015       1.388288   0.172560 -0.121330  Bronze
# wsh016      -0.053761  -0.764196 -0.803742  Bronze
# wsh017       0.426922  -0.061629  0.032733  Bronze
# wsh018      -0.894956   0.406749  0.098895  Bronze
# wsh019      -0.894956   0.875127  0.718925  Bronze
# wsh020      -0.173931   0.640938  0.609286  Bronze
# wsh021      -0.534444   0.406749  0.364487  Bronze
# wsh022       0.306752  -0.647101 -0.943627  Bronze
# wsh023       2.589996  -0.530007 -0.611872  Bronze
# wsh024       1.268118  -0.530007 -0.343445  Bronze
# wsh025       0.787435  -0.998385 -1.020185  Bronze
# wsh026      -0.053761  -1.115479 -1.144003  Bronze
# wsh027      -0.654614  -0.881290 -0.653460  Bronze
# wsh028       1.268118  -0.998385 -1.086347  Bronze
# wsh029      -0.534444  -0.295818 -0.157246  Bronze
# wsh030      -0.654614  -0.295818 -0.599585  Bronze
# wsh031      -0.654614   0.172560  0.494920  Bronze
# wsh032      -0.414273  -0.412912 -0.389758  Bronze
# wsh033       0.186581  -0.998385 -1.144948  Bronze
# wsh034      -0.414273  -0.998385 -0.855726  Bronze
# wsh035      -0.414273  -1.232573 -1.370843  Bronze
# wsh036      -0.294102  -1.349668 -1.394472  Bronze
# wsh037       1.989142  -1.700951 -1.540973  Bronze
# wsh038      -0.774785  -1.583857 -1.535302  Bronze
